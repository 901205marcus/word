# %% [markdown]
# # Word Schedule AI Assistant
#
# 這個 notebook 會在 Colab 直接執行 Word 行程助理。

# %%
# !pip install -q openai>=1.75.0 python-docx>=1.1.2 pydantic>=2.7.0

# %%
import os
os.environ['OPENAI_API_KEY'] = '你的 API Key'

# %%
from colab_runner import run_colab_demo

run_colab_demo()
